# %%
import zipfile
import random
import tensorflow as tf
from tensorflow import keras
import h5py
import os
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import *

from keras import optimizers
import scipy
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import glob
from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import SMOTE
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import imageio
import pandas as pd
from keras.models import *
# Out:
# 2024-10-03 15:35:23.978518: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-03 15:35:24.004867: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-03 15:35:24.004896: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-03 15:35:24.005859: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-03 15:35:24.010598: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-03 15:35:24.536634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
all_data_dir = '/home/user/Desktop/personal/linkon/Alzheimer/OASIS'



print(os.listdir(all_data_dir))
# Out:
# ['Mild Dementia', 'Very mild Dementia', 'Moderate Dementia', 'Non Demented']

# %%
images = []
labels = []

for folder in os.listdir(all_data_dir):
    subfolder_path2=os.path.join(all_data_dir,folder)
    for image_filename in os.listdir(subfolder_path2):
        image_path = os.path.join(subfolder_path2, image_filename)
        images.append(image_path)
        labels.append(folder)
all_df = pd.DataFrame({'image': images, 'label': labels})
all_df
# Out:
#                                                    image          label
# 0      /home/user/Desktop/personal/linkon/Alzheimer/O...  Mild Dementia
# 1      /home/user/Desktop/personal/linkon/Alzheimer/O...  Mild Dementia
# 2      /home/user/Desktop/personal/linkon/Alzheimer/O...  Mild Dementia
# 3      /home/user/Desktop/personal/linkon/Alzheimer/O...  Mild Dementia
# 4      /home/user/Desktop/personal/linkon/Alzheimer/O...  Mild Dementia
# ...                                                  ...            ...
# 86432  /home/user/Desktop/personal/linkon/Alzheimer/O...   Non Demented
# 86433  /home/user/Desktop/personal/linkon/Alzheimer/O...   Non Demented
# 86434  /home/user/Desktop/personal/linkon/Alzheimer/O...   Non Demented
# 86435  /home/user/Desktop/personal/linkon/Alzheimer/O...   Non Demented
# 86436  /home/user/Desktop/personal/linkon/Alzheimer/O...   Non Demented
#
# [86437 rows x 2 columns]

# %%
all_df['label'] = all_df['label'].replace({'Mild Dementia': 'Moderate Dementia'})
all_df['label'] = all_df['label'].replace({'Very mild Dementia': 'Moderate Dementia'})
all_df_edited = all_df[(all_df['label']=='Moderate Dementia') | (all_df['label']=='Non Demented')]


all_df_edited = all_df_edited.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
all_df_edited.head()
# Out:
#                                                image              label
# 0  /home/user/Desktop/personal/linkon/Alzheimer/O...       Non Demented
# 1  /home/user/Desktop/personal/linkon/Alzheimer/O...       Non Demented
# 2  /home/user/Desktop/personal/linkon/Alzheimer/O...       Non Demented
# 3  /home/user/Desktop/personal/linkon/Alzheimer/O...  Moderate Dementia
# 4  /home/user/Desktop/personal/linkon/Alzheimer/O...       Non Demented

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(x=all_df_edited.label, palette='Set2')
ax.set_xlabel("Class", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
plt.title('The Number Of Samples For Each Class in Train', fontsize=20)
plt.grid(False)
plt.xticks(rotation=35)

# Add counts on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points', 
                fontsize=12)

plt.show()
# Out:
# /tmp/ipykernel_1415096/3004188932.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=all_df_edited.label, palette='Set2')

# %%
plt.figure(figsize=(10,12))

for n,i in enumerate(np.random.randint(0,len(all_df_edited),20)):
    plt.subplot(5,5,n+1)
    img=cv2.imread(all_df_edited.image[i])
    img=cv2.resize(img,(128,128))
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.title(all_df_edited.label[i],fontsize=12)

# %%
temp_df_edited, test_df_edited = train_test_split(all_df_edited, test_size=0.15, stratify=all_df_edited['label'], random_state=43)
train_df_edited, val_df_edited = train_test_split(temp_df_edited, test_size=0.15, stratify=temp_df_edited['label'], random_state=43)


train_df_edited = train_df_edited.reset_index(drop=True)
val_df_edited = val_df_edited.reset_index(drop=True)
test_df_edited = test_df_edited.reset_index(drop=True)
train_df_edited.shape, test_df_edited.shape, val_df_edited.shape
# Out:
# ((62450, 2), (12966, 2), (11021, 2))

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(x=test_df_edited.label, palette='Set2')
ax.set_xlabel("Class", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
plt.title('The Number Of Samples For Each Class in TEST', fontsize=20)
plt.grid(False)
plt.xticks(rotation=35)

# Add counts on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points', 
                fontsize=12)

plt.show()
# Out:
# /tmp/ipykernel_1415096/1169724873.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=test_df_edited.label, palette='Set2')

# %%
plt.figure(figsize=(15, 8))
ax = sns.countplot(x=train_df_edited.label, palette='Set2')
ax.set_xlabel("Class", fontsize=20)
ax.set_ylabel("Count", fontsize=20)
plt.title('The Number Of Samples For Each Class in TEST', fontsize=20)
plt.grid(False)
plt.xticks(rotation=35)

# Add counts on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', 
                xytext=(0, 10), 
                textcoords='offset points', 
                fontsize=12)

plt.show()
# Out:
# /tmp/ipykernel_1415096/3995720465.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=train_df_edited.label, palette='Set2')

# %%
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.utils import to_categorical

# %%
image = cv2.imread('/home/user/Desktop/personal/linkon/Alzheimer/OASIS/Mild Dementia/OAS1_0028_MR1_mpr-1_117.jpg')
        
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_rgb = cv2.rotate(image_rgb, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(image_rgb)

# %%
def load_resize_normalize_data(df, target_size=(128, 128)):
    images = []
    labels = []
    
    label_encoder = LabelEncoder()
    for index, row in df.iterrows():
   
        image_path = row['image']
        image = cv2.imread(image_path)
        

        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)# Convert to RGB format
        image_rgb = cv2.rotate(image_rgb, cv2.ROTATE_90_CLOCKWISE)
        resized_image = cv2.resize(image_rgb, (128,128))
        

        normalized_image = resized_image / 255.0 
        
        # Store the resized and normalized image and its corresponding label
        images.append(normalized_image)
        labels.append(row['label'])
  
    encoded_labels_lb = label_encoder.fit_transform(labels)
    
    class_mapping ={ 'Non Demented': 1,  'Moderate Dementia':0}
    
    y_mapped =df['label'].map(class_mapping)
    y_one_hot = to_categorical(y_mapped, num_classes=2)
    return np.array(images), np.array(encoded_labels_lb), label_encoder.classes_, y_one_hot

# %%
train_images, train_encoded_labels, classes, train_one_hot = load_resize_normalize_data(train_df_edited)

# %%
train_datagen = ImageDataGenerator(rotation_range=15, width_shift_range=0.1, 
    height_shift_range=0.1, shear_range=0.2, zoom_range=0.2, 
     horizontal_flip=True)

# %%
label_decoder = {1: 'Non Demented',  0: 'Moderate Dementia'}

plt.figure(figsize=(10, 12))

for n, i in enumerate(np.random.randint(0, len(train_images), 20)):
    plt.subplot(5, 5, n + 1)
    img = train_images[i]
    plt.imshow(img)
    plt.axis('off')
    plt.title(label_decoder[train_encoded_labels[i]], fontsize=12)

plt.tight_layout()

# %%
train_gen = train_datagen.flow(train_images, train_one_hot, batch_size=8, shuffle=True)

# %% [markdown]
# # Val Processing

# %%
val_images, val_encoded_labels, val_classes, val_one_hot = load_resize_normalize_data(val_df_edited)

# %%
print("Shape of images array:", val_images.shape)
print("Shape of encoded labels array:", val_encoded_labels.shape)
print("Classes:", val_classes)
# print("One HOt clases:", val_one_hot)
print("One HOt clases:", val_one_hot.shape)
# Out:
# Shape of images array: (11021, 128, 128, 3)
# Shape of encoded labels array: (11021,)
# Classes: ['Moderate Dementia' 'Non Demented']
# One HOt clases: (11021, 2)

# %%
label_decoder = {1: 'Non Demented',  0: 'Moderate Dementia'}

plt.figure(figsize=(10, 12))

for n, i in enumerate(np.random.randint(0, len(val_images), 20)):
    plt.subplot(5, 5, n + 1)
    img = val_images[i]
    plt.imshow(img)
    plt.axis('off')
    plt.title(label_decoder[val_encoded_labels[i]], fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test preprocessing

# %%
test_images, test_encoded_labels, test_classes, test_one_hot = load_resize_normalize_data(test_df_edited)

# %%
print("Shape of images array:", test_images.shape)
print("Shape of encoded labels array:", test_encoded_labels.shape)
print("Classes:", test_classes)
# print("One HOt clases:", test_one_hot)
print("One HOt clases:", test_one_hot.shape)
# Out:
# Shape of images array: (12966, 128, 128, 3)
# Shape of encoded labels array: (12966,)
# Classes: ['Moderate Dementia' 'Non Demented']
# One HOt clases: (12966, 2)

# %%
label_decoder = {1: 'Non Demented',  0: 'Moderate Dementia'}

plt.figure(figsize=(10, 12))

for n, i in enumerate(np.random.randint(0, len(test_images), 20)):
    plt.subplot(5, 5, n + 1)
    img = test_images[i]
    plt.imshow(img)
    plt.axis('off')
    plt.title(label_decoder[test_encoded_labels[i]], fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data generator

# %%
valid_datagen = ImageDataGenerator(
    preprocessing_function=None 
)

# %%
batch_size=8
val_gen = valid_datagen.flow(val_images, val_one_hot, batch_size=8, shuffle=False)
test_gen = valid_datagen.flow(test_images, test_one_hot, batch_size=1, shuffle=False)

# %%
from keras import backend as K

IMG_CHANNELS=3
IMG_WIDTH = 128
IMG_HEIGHT = 128

if K.image_data_format() == 'channels_first':
    input_shape = (IMG_CHANNELS, IMG_WIDTH, IMG_HEIGHT)
else:
    input_shape = (IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.layers import *
initial_learning_rate = 0.0001
lr_schedule = ExponentialDecay(
        initial_learning_rate,
        decay_steps=10000,
        decay_rate=0.8,
        staircase=True)


print(lr_schedule.get_config())
# Out:
# {'initial_learning_rate': 0.0001, 'decay_steps': 10000, 'decay_rate': 0.8, 'staircase': True, 'name': None}

# %%
class ExpandDimsLayer(Layer):
    def __init__(self, axis, **kwargs):
        super(ExpandDimsLayer, self).__init__(**kwargs)
        self.axis = axis

    def call(self, inputs):
        return tf.expand_dims(inputs, axis=self.axis)

# %%
class Reshapelayer(Layer):
    def __init__(self, dim, **kwargs):
        super(Reshapelayer, self).__init__(**kwargs)
        self.dim = dim

    def call(self, inputs):
        return tf.reshape(inputs, [tf.shape(inputs)[0], self.dim, 1])

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.dim, 1)
    
    
class ReduceMeanLayer(Layer):
    def __init__(self, axis, **kwargs):
        super(ReduceMeanLayer, self).__init__(**kwargs)
        self.axis = axis

    def call(self, inputs):
        return tf.reduce_mean(inputs, axis=self.axis)

# %%
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
class RootMeanSquaredError(tf.keras.metrics.Metric):
    def __init__(self, name='rmse', **kwargs):
        super(RootMeanSquaredError, self).__init__(name=name, **kwargs)
        self.mse = tf.keras.metrics.MeanSquaredError()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.mse.update_state(y_true, y_pred, sample_weight)

    def result(self):
        return tf.sqrt(self.mse.result())

    def reset_states(self):
        self.mse.reset_states()

# %%
def line1(x):
    # received shape: (64, 64, 3)
    conv_1 = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
#     pool_1 = MaxPool2D(pool_size=(2, 2))(conv_1)
    
    # Increase to 3D
    reshaped_1 = ExpandDimsLayer(axis=-1)(conv_1)
    print("received shape:", reshaped_1.shape)
    maxpool_1 = MaxPool3D(pool_size=(3, 3, 3))(reshaped_1)
    print("line_1 maxpool ", maxpool_1.shape)
#     extra_line_1 = line3D_1(maxpool_1)
    
    
    block1_conv1 = Conv2D(32, (1, 1), activation='relu', padding='same')(conv_1)
    block1_pool = MaxPool2D(2, 2)(block1_conv1)

    block2_conv1 = Conv2D(64, (7, 7), activation='relu', padding='same')(block1_pool)
    block2_pool = MaxPool2D(2, 2)(block2_conv1)

    global_pool = GlobalAveragePooling2D()(block2_conv1)
    fully_connected_1 = Dense(128, activation='relu')(global_pool)

    return fully_connected_1#, extra_line_1

def line2(x):
    # received shape: (32, 32, 3)
    print("received shape: line_2", x.shape)

    conv_1 = Conv2D(64, (7, 7), activation='relu', padding='same')(x)
   
    # increase dimension
    reshaped_1 = ExpandDimsLayer(axis=-1)(conv_1)
    block1_pool = MaxPool3D(pool_size=(3, 3, 3,))(reshaped_1)
    
    
    print("received shape: line_2Pool ", block1_pool.shape)
#     extra_line_1 = line3D_1(block1_pool)
#     print("received shape: extra_line2 ",extra_line_1.shape)
    
    

    block1_conv1 = Conv2D(32, (5, 5), activation='relu', padding='same')(conv_1)
    block1_pool = MaxPool2D(2, 2)(block1_conv1)

    
    global_pool = GlobalAveragePooling2D()(block1_pool)
    global_pool = Dropout(0.2)(global_pool)

    fully_connected_1 = Dense(128, activation='relu')(global_pool)
    fully_connected_1 = Dropout(0.2)(fully_connected_1)

    return fully_connected_1#, extra_line_1

def line3(x):
    # received shape: (16, 16, 3)
    print("received shape: (16, 16, 3)", x.shape)

    conv_1 = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    reshaped_1 = ExpandDimsLayer(axis=-1)(conv_1)
#     extra_line_1 = line3D_1(reshaped_1)

    block1_conv1 = Conv2D(32, (2, 2), activation='relu', padding='same')(conv_1)
#     block1_pool = MaxPool2D(2, 2)(block1_conv1)

    block2_conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(block1_conv1)
    block2_pool = AvgPool2D(2, 2)(block2_conv1)

    global_pool = GlobalAveragePooling2D()(block2_pool)

    fully_connected_1 = Dense(128, activation='relu')(global_pool)
    return fully_connected_1#, extra_line_1

def line3D_1(x):
    # For the 3D convolution
    print("Line3d shape", x.shape)
#     conv_1 = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
#     print("Line3d conv1_shape", conv_1.shape)

#     reshaped_2 = tf.expand_dims(conv_1, axis=-1)
#     print(reshaped_2.shape)
    conv_1 = Conv3D(32, (4, 4, 4), activation='relu', padding='same')(x)
#     conv_1 = MaxPool3D(pool_size=(2, 2, 2))(conv_1)
    conv_1 = Conv3D(64, (2, 2, 2), activation='relu', padding='same')(conv_1)
#     conv_1 = MaxPool3D(pool_size=(2, 2, 2))(conv_1)
    conv_1 = Conv3D(128, (2, 2, 2), activation='relu', padding='same')(conv_1)
#     conv_1 = MaxPool3D(pool_size=(2, 2, 2))(conv_1)
    conv_1 = GlobalAveragePooling3D()(conv_1)
    conv_1 = Dropout(0.3)(conv_1)
    out = Dense(128, activation='relu')(conv_1)
    return out

def line4(x):
    # The LSTM network after the 2D Sub-unit
    # received shape: (16, 16, 3)
    print("received shape: (16, 16, 3)", x.shape)
    conv_1 = Conv2D(512, (14, 14), activation='relu', padding='same')(x)
    conv_1 = MaxPool2D(pool_size=(2,2))(conv_1)
    conv_1 = BatchNormalization()(conv_1)
    reshaped = Reshape((conv_1.shape[1] * conv_1.shape[2], conv_1.shape[3]))(conv_1)
    lstm_1 = LSTM(12, return_sequences=False)(reshaped)
    flat = Flatten()(lstm_1)
    out = Dense(128, activation='relu')(flat)
    return out

def line5(x):
    # The parallel sequential LSTM feature optimizer
    print(x.shape)
    reshaped = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)  # Reshape for LSTM
    x = BatchNormalization()(reshaped)
    lstm1 = Bidirectional(LSTM(16, return_sequences=False))(x)
    out = Dense(128, activation='relu')(lstm1)
    return out

# %%
def get_model(num_classes):
    signal = Input(shape=(128, 128, 3), dtype=np.float32, name='signal')
    f_lstm = line5(signal)

    # converting to (32, 32, 3):
    conv_1 = Conv2D(64, (5,5), activation='relu', padding='same', strides=1)(signal)
    conv_1 = MaxPool2D(pool_size=(2,2))(conv_1)  # (32, 32, 3)
    print("Conv1", conv_1.shape)

#     f1, f1_3d = line1(conv_1)
#     print(f1.shape, f1_3d.shape)
    f1 = line1(conv_1)
    print(f1.shape)

    # converting to (16, 16, 3):
    conv_1 = Conv2D(128, (5, 5), activation='relu', padding='same', strides=1)(conv_1)
    conv_1 = MaxPool2D(pool_size=(3,3))(conv_1)  # (16, 16, 3)
    print("Conv1_2", conv_1.shape)

#     f2, f2_3d = line2(conv_1)
    f2 = line2(conv_1)

    # converting to (8, 8, 3):
    conv_1 = Conv2D(128, (5, 5), activation='relu', padding='same', strides=1)(conv_1)
    conv_1 = MaxPool2D(4)(conv_1)  # (8, 8, 3)

#     f3, f3_3d = line3(conv_1)
    f3= line3(conv_1)

    # converting to (8, 8, 3): # same input for line4 function
    f4 = line4(conv_1)

  
    
    f1 = Reshapelayer(dim=128)(f1)
    f2 = Reshapelayer(dim=128)(f2)
    f3 = Reshapelayer(dim=128)(f3) 
    f4 = Reshapelayer(dim=128)(f4) #tf.reshape(f4, [tf.shape(signal)[0], 128, 1])
    f5 = Reshapelayer(dim=128)(f_lstm)
#     f6 = Reshapelayer(dim=128)(f1_3d) 
#     f7 = Reshapelayer(dim=128)(f2_3d)
#     f8 = Reshapelayer(dim=128)(f3_3d)

    concat = Concatenate()([f1, f2, f3, f4, f5])#, f6, f7, f8])
#     concat = tf.reduce_mean(concat, axis=2)
    concat = ReduceMeanLayer(axis=2)(concat)

    dense_1 = Dense(128, activation='relu')(concat)
    dense_2 = Dense(32, activation='relu')(dense_1)
    out = Dense(num_classes, activation='softmax')(dense_2)

    model = Model(inputs=signal, outputs=[out])
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),  metrics=[tf.keras.metrics.CategoricalAccuracy(
                    name='accuracy'),tf.keras.metrics.Recall(name='Recall'),tf.keras.metrics.Precision(name='Precision'), 
                    tf.keras.metrics.AUC(num_thresholds=200,curve="ROC",summation_method="interpolation",name="AUC",dtype=None,thresholds=None,
                    multi_label=True,label_weights=None,),
                    tf.keras.metrics.FalsePositives(), tf.keras.metrics.FalseNegatives(),
                    F1Score(name='f1_score'),
                    tf.keras.metrics.MeanAbsoluteError(name='MAE'),
                    tf.keras.metrics.MeanAbsolutePercentageError(name='MAPE'),
                    RootMeanSquaredError(name='RMSE')]) 
    
    return model

if __name__ == "__main__":
    model = get_model(2)
    model.summary()
# Out:
# (None, 128, 128, 3)
# 2024-10-03 15:36:59.898716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.924910: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.925049: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.925862: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.925961: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.926017: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.968358: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.968480: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.968552: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-03 15:36:59.968607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1165 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-03 15:37:00.026222: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Conv1 (None, 64, 64, 64)
# received shape: (None, 64, 64, 256, 1)
# line_1 maxpool  (None, 21, 21, 85, 1)
# (None, 128)
# Conv1_2 (None, 21, 21, 128)
# received shape: line_2 (None, 21, 21, 128)
# received shape: line_2Pool  (None, 7, 7, 21, 1)
# received shape: (16, 16, 3) (None, 5, 5, 128)
# received shape: (16, 16, 3) (None, 5, 5, 128)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  signal (InputLayer)         [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 64)         4864      ['signal[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 64)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)          204928    ['max_pooling2d[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 21, 21, 128)          0         ['conv2d_4[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 21, 21, 128)          409728    ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 128)            0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 21, 21, 64)           401472    ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 5, 5, 512)            1284556   ['max_pooling2d_5[0][0]']
#                                                           8
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 256)          147712    ['max_pooling2d[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 21, 21, 32)           51232     ['conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 5, 5, 16)             18448     ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 2, 2, 512)            0         ['conv2d_11[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)           8224      ['conv2d_1[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 10, 10, 32)           0         ['conv2d_6[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 5, 5, 32)             2080      ['conv2d_8[0][0]']
#
#  batch_normalization_1 (Bat  (None, 2, 2, 512)            2048      ['max_pooling2d_6[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)           0         ['conv2d_2[0][0]']
#  g2D)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['max_pooling2d_4[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_10 (Conv2D)          (None, 5, 5, 64)             18496     ['conv2d_9[0][0]']
#
#  reshape_1 (Reshape)         (None, 4, 512)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  reshape (Reshape)           (None, 16384, 3)             0         ['signal[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)           100416    ['max_pooling2d_1[0][0]']
#
#  dropout (Dropout)           (None, 32)                   0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  average_pooling2d (Average  (None, 2, 2, 64)             0         ['conv2d_10[0][0]']
#  Pooling2D)
#
#  lstm_1 (LSTM)               (None, 12)                   25200     ['reshape_1[0][0]']
#
#  batch_normalization (Batch  (None, 16384, 3)             12        ['reshape[0][0]']
#  Normalization)
#
#  global_average_pooling2d (  (None, 64)                   0         ['conv2d_3[0][0]']
#  GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)                  4224      ['dropout[0][0]']
#
#  global_average_pooling2d_2  (None, 64)                   0         ['average_pooling2d[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 12)                   0         ['lstm_1[0][0]']
#
#  bidirectional (Bidirection  (None, 32)                   2560      ['batch_normalization[0][0]']
#  al)
#
#  dense_1 (Dense)             (None, 128)                  8320      ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  8320      ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_4 (Dense)             (None, 128)                  1664      ['flatten[0][0]']
#
#  dense (Dense)               (None, 128)                  4224      ['bidirectional[0][0]']
#
#  reshapelayer (Reshapelayer  (None, 128, 1)               0         ['dense_1[0][0]']
#  )
#
#  reshapelayer_1 (Reshapelay  (None, 128, 1)               0         ['dropout_1[0][0]']
#  er)
#
#  reshapelayer_2 (Reshapelay  (None, 128, 1)               0         ['dense_3[0][0]']
#  er)
#
#  reshapelayer_3 (Reshapelay  (None, 128, 1)               0         ['dense_4[0][0]']
#  er)
#
#  reshapelayer_4 (Reshapelay  (None, 128, 1)               0         ['dense[0][0]']
#  er)
#
#  concatenate (Concatenate)   (None, 128, 5)               0         ['reshapelayer[0][0]',
#                                                                      'reshapelayer_1[0][0]',
#                                                                      'reshapelayer_2[0][0]',
#                                                                      'reshapelayer_3[0][0]',
#                                                                      'reshapelayer_4[0][0]']
#
#  reduce_mean_layer (ReduceM  (None, 128)                  0         ['concatenate[0][0]']
#  eanLayer)
#
#  dense_5 (Dense)             (None, 128)                  16512     ['reduce_mean_layer[0][0]']
#
#  dense_6 (Dense)             (None, 32)                   4128      ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 2)                    66        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 14290446 (54.51 MB)
# Trainable params: 14289416 (54.51 MB)
# Non-trainable params: 1030 (4.02 KB)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='./Proposed_Model.png')

# %%
from tensorflow.keras.callbacks import Callback 
class LearningRateSchedulerWithPatienceIoU(Callback):
    def __init__(self, reduce_lr_factor, patience, min_lr, monitor='val_iou'):
        super(LearningRateSchedulerWithPatienceIoU, self).__init__()
        self.reduce_lr_factor = reduce_lr_factor
        self.patience = patience
        self.min_lr = min_lr
        self.monitor = monitor
        self.wait = 0
        self.best_iou = -float('inf')
#         self.model = model
        
    def on_epoch_end(self, epoch, logs=None):
        current_iou = logs.get(self.monitor, -float('inf'))
        
        if current_iou > self.best_iou:
            self.best_iou = current_iou
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                new_lr = self.model.optimizer.learning_rate.numpy() * self.reduce_lr_factor
                print(new_lr)
                new_lr = max(new_lr, self.min_lr)
                
                self.model.optimizer.learning_rate.assign(new_lr)
                print(f"\nReduced learning rate to {new_lr} after {self.patience} epochs without improvement in IoU.\n")
                self.wait = 0

# %%
# initial_learning_rate = 0.00075  # Initial learning rate
# reduce_lr_factor = 0.5  # Factor by which to reduce the learning rate
# patience = 1  # Number of epochs without improvement in IoU before reducing learning rate
# min_learning_rate = 1e-6  # Minimum learning rate

# # Create the custom learning rate scheduler
# lr_scheduler = LearningRateSchedulerWithPatienceIoU(reduce_lr_factor, patience, min_learning_rate)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
lr_plateu = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-6, verbose=1)

# %%
train_one_hot.shape
# Out:
# (62450, 2)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint_path = "/home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(train_gen,epochs=50, validation_data=(val_gen),  callbacks=[checkpoint, lr_plateu],verbose=1)
# Out:
# Epoch 1/50
# 2024-10-03 15:37:06.080915: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-10-03 15:37:06.152748: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-10-03 15:37:06.633643: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:06.633679: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:06.702031: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:06.702071: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:07.671367: I external/local_xla/xla/service/service.cc:168] XLA service 0x752f40700c90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-03 15:37:07.671390: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050, Compute Capability 8.6
# 2024-10-03 15:37:07.675084: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727948227.748222 1415429 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-10-03 15:37:12.268719: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:12.405609: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  111/7807 [..............................] - ETA: 52:12 - loss: 0.5504 - accuracy: 0.7624 - Recall: 0.7624 - Precision: 0.7624 - AUC: 0.5492 - false_positives: 211.0000 - false_negatives: 211.0000 - f1_score: 0.7624 - MAE: 0.3670 - MAPE: 183501312.0000 - RMSE: 0.4271
# 2024-10-03 15:37:57.915078: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:57.915114: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:57.948664: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-10-03 15:37:57.948696: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 7807/7807 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8155 - Recall: 0.8155 - Precision: 0.8155 - AUC: 0.8489 - false_positives: 11522.0000 - false_negatives: 11522.0000 - f1_score: 0.8155 - MAE: 0.2510 - MAPE: 125512880.0000 - RMSE: 0.3529
# /home/user/anaconda3/envs/ecg/lib/python3.9/site-packages/keras/src/engine/training.py:2723: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# /home/user/anaconda3/envs/ecg/lib/python3.9/site-packages/keras/src/engine/training.py:2723: UserWarning: Metric RootMeanSquaredError implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.78822, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3445s 440ms/step - loss: 0.3808 - accuracy: 0.8155 - Recall: 0.8155 - Precision: 0.8155 - AUC: 0.8489 - false_positives: 11522.0000 - false_negatives: 11522.0000 - f1_score: 0.8155 - MAE: 0.2510 - MAPE: 125512880.0000 - RMSE: 0.3529 - val_loss: 0.3831 - val_accuracy: 0.7882 - val_Recall: 0.7882 - val_Precision: 0.7882 - val_AUC: 0.9266 - val_false_positives: 2334.0000 - val_false_negatives: 2334.0000 - val_f1_score: 0.7882 - val_MAE: 0.2599 - val_MAPE: 129928944.0000 - val_RMSE: 0.3613 - lr: 1.0000e-04
# Epoch 2/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8653 - Recall: 0.8653 - Precision: 0.8653 - AUC: 0.9236 - false_positives: 8413.0000 - false_negatives: 8413.0000 - f1_score: 0.8653 - MAE: 0.1844 - MAPE: 92203680.0000 - RMSE: 0.3032
# Epoch 2: val_accuracy improved from 0.78822 to 0.87905, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 
50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9544 - Recall: 0.9544 - Precision: 0.9544 - AUC: 0.9884 - false_positives: 2845.0000 - false_negatives: 2845.0000 - f1_score: 0.9544 - MAE: 0.0667 - MAPE: 33325724.0000 - RMSE: 0.1824
# Epoch 6: val_accuracy improved from 0.95445 to 0.97323, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3436s 440ms/step - loss: 0.1120 - accuracy: 0.9544 - Recall: 0.9544 - Precision: 0.9544 - AUC: 0.9884 - false_positives: 2845.0000 - false_negatives: 2845.0000 - f1_score: 0.9544 - MAE: 0.0667 - MAPE: 33325724.0000 - RMSE: 0.1824 - val_loss: 0.0709 - val_accuracy: 0.9732 - val_Recall: 0.9732 - val_Precision: 0.9732 - val_AUC: 0.9963 - val_false_positives: 295.0000 - val_false_negatives: 295.0000 - val_f1_score: 0.9732 - val_MAE: 0.0398 - val_MAPE: 19902612.0000 - val_RMSE: 0.1424 - lr: 1.0000e-04
# Epoch 7/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9631 - Recall: 0.9631 - Precision: 0.9631 - AUC: 0.9919 - false_positives: 2306.0000 - false_negatives: 2306.0000 - f1_score: 0.9631 - MAE: 0.0552 - MAPE: 27600102.0000 - RMSE: 0.1663
# Epoch 7: val_accuracy did not improve from 0.97323
# 7807/7807 [==============================] - 3437s 440ms/step - loss: 0.0939 - accuracy: 0.9631 - Recall: 0.9631 - Precision: 0.9631 - AUC: 0.9919 - false_positives: 2306.0000 - false_negatives: 2306.0000 - f1_score: 0.9631 - MAE: 0.0552 - MAPE: 27600102.0000 - RMSE: 0.1663 - val_loss: 0.1961 - val_accuracy: 0.9220 - val_Recall: 0.9220 - val_Precision: 0.9220 - val_AUC: 0.9905 - val_false_positives: 860.0000 - val_false_negatives: 860.0000 - val_f1_score: 0.9220 - val_MAE: 0.0951 - val_MAPE: 47567004.0000 - val_RMSE: 0.2422 - lr: 1.0000e-04
# Epoch 8/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9690 - Recall: 0.9690 - Precision: 0.9690 - AUC: 0.9941 - false_positives: 1937.0000 - false_negatives: 1937.0000 - f1_score: 0.9690 - MAE: 0.0457 - MAPE: 22831340.0000 - RMSE: 0.1511
# Epoch 8: val_accuracy did not improve from 0.97323
# 7807/7807 [==============================] - 3441s 441ms/step - loss: 0.0782 - accuracy: 0.9690 - Recall: 0.9690 - Precision: 0.9690 - AUC: 0.9941 - false_positives: 1937.0000 - false_negatives: 1937.0000 - f1_score: 0.9690 - MAE: 0.0457 - MAPE: 22831340.0000 - RMSE: 0.1511 - val_loss: 0.2469 - val_accuracy: 0.9047 - val_Recall: 0.9047 - val_Precision: 0.9047 - val_AUC: 0.9922 - val_false_positives: 1050.0000 - val_false_negatives: 1050.0000 - val_f1_score: 0.9047 - val_MAE: 0.1047 - val_MAPE: 52343464.0000 - val_RMSE: 0.2683 - lr: 1.0000e-04
# Epoch 9/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9734 - Recall: 0.9734 - Precision: 0.9734 - AUC: 0.9950 - false_positives: 1659.0000 - false_negatives: 1659.0000 - f1_score: 0.9734 - MAE: 0.0396 - MAPE: 19785866.0000 - RMSE: 0.1406
# Epoch 9: val_accuracy improved from 0.97323 to 0.98058, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3440s 441ms/step - loss: 0.0690 - accuracy: 0.9734 - Recall: 0.9734 - Precision: 0.9734 - AUC: 0.9950 - false_positives: 1659.0000 - false_negatives: 1659.0000 - f1_score: 0.9734 - MAE: 0.0396 - MAPE: 19785866.0000 - RMSE: 0.1406 - val_loss: 0.0522 - val_accuracy: 0.9806 - val_Recall: 0.9806 - val_Precision: 0.9806 - val_AUC: 0.9975 - val_false_positives: 214.0000 - val_false_negatives: 214.0000 - val_f1_score: 0.9806 - val_MAE: 0.0266 - val_MAPE: 13319844.0000 - val_RMSE: 0.1211 - lr: 1.0000e-04
# Epoch 10/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9762 - Recall: 0.9762 - Precision: 0.9762 - AUC: 0.9961 - false_positives: 1488.0000 - false_negatives: 1488.0000 - f1_score: 0.9762 - MAE: 0.0354 - MAPE: 17690308.0000 - RMSE: 0.1331
# Epoch 10: val_accuracy did not improve from 0.98058
# 7807/7807 [==============================] - 3449s 442ms/step - loss: 0.0621 - accuracy: 0.9762 - Recall: 0.9762 - Precision: 0.9762 - AUC: 0.9961 - false_positives: 1488.0000 - false_negatives: 1488.0000 - f1_score: 0.9762 - MAE: 0.0354 - MAPE: 17690308.0000 - RMSE: 0.1331 - val_loss: 0.0920 - val_accuracy: 0.9667 - val_Recall: 0.9667 - val_Precision: 0.9667 - val_AUC: 0.9948 - val_false_positives: 367.0000 - val_false_negatives: 367.0000 - val_f1_score: 0.9667 - val_MAE: 0.0414 - val_MAPE: 20700906.0000 - val_RMSE: 0.1605 - lr: 1.0000e-04
# Epoch 11/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9793 - Recall: 0.9793 - Precision: 0.9793 - AUC: 0.9968 - false_positives: 1294.0000 - false_negatives: 1294.0000 - f1_score: 0.9793 - MAE: 0.0311 - MAPE: 15544892.0000 - RMSE: 0.1250
# Epoch 11: val_accuracy improved from 0.98058 to 0.99093, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3450s 442ms/step - loss: 0.0549 - accuracy: 0.9793 - Recall: 0.9793 - Precision: 0.9793 - AUC: 0.9968 - false_positives: 1294.0000 - false_negatives: 1294.0000 - f1_score: 0.9793 - MAE: 0.0311 - MAPE: 15544892.0000 - RMSE: 0.1250 - val_loss: 0.0268 - val_accuracy: 0.9909 - val_Recall: 0.9909 - val_Precision: 0.9909 - val_AUC: 0.9991 - val_false_positives: 100.0000 - val_false_negatives: 100.0000 - val_f1_score: 0.9909 - val_MAE: 0.0167 - val_MAPE: 8337190.5000 - val_RMSE: 0.0858 - lr: 1.0000e-04
# Epoch 12/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.
# 7807/7807 [==============================] - 3448s 442ms/step - loss: 0.0374 - accuracy: 0.9861 - Recall: 0.9861 - Precision: 0.9861 - AUC: 0.9983 - false_positives: 866.0000 - false_negatives: 866.0000 - f1_score: 0.9861 - MAE: 0.0211 - MAPE: 10543239.0000 - RMSE: 0.1028 - val_loss: 0.0759 - val_accuracy: 0.9759 - val_Recall: 0.9759 - val_Precision: 0.9759 - val_AUC: 0.9968 - val_false_positives: 266.0000 - val_false_negatives: 266.0000 - val_f1_score: 0.9759 - val_MAE: 0.0285 - val_MAPE: 14244722.0000 - val_RMSE: 0.1383 - lr: 1.0000e-04
# Epoch 16/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9869 - Recall: 0.9869 - Precision: 0.9869 - AUC: 0.9985 - false_positives: 816.0000 - false_negatives: 816.0000 - f1_score: 0.9869 - MAE: 0.0195 - MAPE: 9740497.0000 - RMSE: 0.0994
# Epoch 16: val_accuracy did not improve from 0.99093
# 7807/7807 [==============================] - 3445s 441ms/step - loss: 0.0350 - accuracy: 0.9869 - Recall: 0.9869 - Precision: 0.9869 - AUC: 0.9985 - false_positives: 816.0000 - false_negatives: 816.0000 - f1_score: 0.9869 - MAE: 0.0195 - MAPE: 9740497.0000 - RMSE: 0.0994 - val_loss: 0.0429 - val_accuracy: 0.9848 - val_Recall: 0.9848 - val_Precision: 0.9848 - val_AUC: 0.9986 - val_false_positives: 167.0000 - val_false_negatives: 167.0000 - val_f1_score: 0.9848 - val_MAE: 0.0189 - val_MAPE: 9438336.0000 - val_RMSE: 0.1069 - lr: 1.0000e-04
# Epoch 17/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9885 - Recall: 0.9885 - Precision: 0.9885 - AUC: 0.9984 - false_positives: 719.0000 - false_negatives: 719.0000 - f1_score: 0.9885 - MAE: 0.0177 - MAPE: 8863245.0000 - RMSE: 0.0943
# Epoch 17: val_accuracy improved from 0.99093 to 0.99728, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3444s 441ms/step - loss: 0.0323 - accuracy: 0.9885 - Recall: 0.9885 - Precision: 0.9885 - AUC: 0.9984 - false_positives: 719.0000 - false_negatives: 719.0000 - f1_score: 0.9885 - MAE: 0.0177 - MAPE: 8863245.0000 - RMSE: 0.0943 - val_loss: 0.0099 - val_accuracy: 0.9973 - val_Recall: 0.9973 - val_Precision: 0.9973 - val_AUC: 0.9999 - val_false_positives: 30.0000 - val_false_negatives: 30.0000 - val_f1_score: 0.9973 - val_MAE: 0.0062 - val_MAPE: 3102543.0000 - val_RMSE: 0.0500 - lr: 1.0000e-04
# Epoch 18/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9887 - Recall: 0.9887 - Precision: 0.9887 - AUC: 0.9987 - false_positives: 707.0000 - false_negatives: 707.0000 - f1_score: 0.9887 - MAE: 0.0172 - MAPE: 8598885.0000 - RMSE: 0.0933
# Epoch 18: val_accuracy did not improve from 0.99728
# 7807/7807 [==============================] - 3476s 445ms/step - loss: 0.0312 - accuracy: 0.9887 - Recall: 0.9887 - Precision: 0.9887 - AUC: 0.9987 - false_positives: 707.0000 - false_negatives: 707.0000 - f1_score: 0.9887 - MAE: 0.0172 - MAPE: 8598885.0000 - RMSE: 0.0933 - val_loss: 0.0281 - val_accuracy: 0.9898 - val_Recall: 0.9898 - val_Precision: 0.9898 - val_AUC: 0.9987 - val_false_positives: 112.0000 - val_false_negatives: 112.0000 - val_f1_score: 0.9898 - val_MAE: 0.0140 - val_MAPE: 6987933.0000 - val_RMSE: 0.0877 - lr: 1.0000e-04
# Epoch 19/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.
50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9970 - Recall: 0.9970 - Precision: 0.9970 - AUC: 0.9998 - false_positives: 189.0000 - false_negatives: 189.0000 - f1_score: 0.9970 - MAE: 0.0045 - MAPE: 2263985.0000 - RMSE: 0.0483
# Epoch 33: val_accuracy did not improve from 0.99755
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0087 - accuracy: 0.9970 - Recall: 0.9970 - Precision: 0.9970 - AUC: 0.9998 - false_positives: 189.0000 - false_negatives: 189.0000 - f1_score: 0.9970 - MAE: 0.0045 - MAPE: 2263985.0000 - RMSE: 0.0483 - val_loss: 0.0099 - val_accuracy: 0.9966 - val_Recall: 0.9966 - val_Precision: 0.9966 - val_AUC: 0.9993 - val_false_positives: 38.0000 - val_false_negatives: 38.0000 - val_f1_score: 0.9966 - val_MAE: 0.0048 - val_MAPE: 2381893.0000 - val_RMSE: 0.0516 - lr: 5.0000e-05
# Epoch 34/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9968 - Recall: 0.9968 - Precision: 0.9968 - AUC: 0.9998 - false_positives: 201.0000 - false_negatives: 201.0000 - f1_score: 0.9968 - MAE: 0.0047 - MAPE: 2365997.5000 - RMSE: 0.0493
# Epoch 34: val_accuracy did not improve from 0.99755
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 7807/7807 [==============================] - 3478s 446ms/step - loss: 0.0089 - accuracy: 0.9968 - Recall: 0.9968 - Precision: 0.9968 - AUC: 0.9998 - false_positives: 201.0000 - false_negatives: 201.0000 - f1_score: 0.9968 - MAE: 0.0047 - MAPE: 2365997.5000 - RMSE: 0.0493 - val_loss: 0.0105 - val_accuracy: 0.9965 - val_Recall: 0.9965 - val_Precision: 0.9965 - val_AUC: 0.9994 - val_false_positives: 39.0000 - val_false_negatives: 39.0000 - val_f1_score: 0.9965 - val_MAE: 0.0045 - val_MAPE: 2242221.5000 - val_RMSE: 0.0514 - lr: 5.0000e-05
# Epoch 35/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9982 - Recall: 0.9982 - Precision: 0.9982 - AUC: 0.9999 - false_positives: 110.0000 - false_negatives: 110.0000 - f1_score: 0.9982 - MAE: 0.0027 - MAPE: 1341749.8750 - RMSE: 0.0356
# Epoch 35: val_accuracy improved from 0.99755 to 0.99864, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3478s 446ms/step - loss: 0.0046 - accuracy: 0.9982 - Recall: 0.9982 - Precision: 0.9982 - AUC: 0.9999 - false_positives: 110.0000 - false_negatives: 110.0000 - f1_score: 0.9982 - MAE: 0.0027 - MAPE: 1341749.8750 - RMSE: 0.0356 - val_loss: 0.0042 - val_accuracy: 0.9986 - val_Recall: 0.9986 - val_Precision: 0.9986 - val_AUC: 0.9999 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_f1_score: 0.9986 - val_MAE: 0.0016 - val_MAPE: 816119.3750 - val_RMSE: 0.0313 - lr: 2.5000e-05
# Epoch 36/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 100.0000 - false_negatives: 100.0000 - f1_score: 0.9984 - MAE: 0.0023 - MAPE: 1155611.6250 - RMSE: 0.0345
# Epoch 36: val_accuracy improved from 0.99864 to 0.99900, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3482s 446ms/step - loss: 0.0045 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 100.0000 - false_negatives: 100.0000 - f1_score: 0.9984 - MAE: 0.0023 - MAPE: 1155611.6250 - RMSE: 0.0345 - val_loss: 0.0022 - val_accuracy: 0.9990 - val_Recall: 0.9990 - val_Precision: 0.9990 - val_AUC: 1.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_f1_score: 0.9990 - val_MAE: 0.0014 - val_MAPE: 686773.1250 - val_RMSE: 0.0251 - lr: 2.5000e-05
# Epoch 37/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 101.0000 - false_negatives: 101.0000 - f1_score: 0.9984 - MAE: 0.0023 - MAPE: 1173568.0000 - RMSE: 0.0348
# Epoch 37: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3480s 446ms/step - loss: 0.0043 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 101.0000 - false_negatives: 101.0000 - f1_score: 0.9984 - MAE: 0.0023 - MAPE: 1173568.0000 - RMSE: 0.0348 - val_loss: 0.0071 - val_accuracy: 0.9975 - val_Recall: 0.9975 - val_Precision: 0.9975 - val_AUC: 0.9999 - val_false_positives: 28.0000 - val_false_negatives: 28.0000 - val_f1_score: 0.9975 - val_MAE: 0.0030 - val_MAPE: 1482264.6250 - val_RMSE: 0.0442 - lr: 2.5000e-05
# Epoch 38/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 102.0000 - false_negatives: 102.0000 - f1_score: 0.9984 - MAE: 0.0025 - MAPE: 1268666.0000 - RMSE: 0.0365
# Epoch 38: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3480s 446ms/step - loss: 0.0050 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 102.0000 - false_negatives: 102.0000 - f1_score: 0.9984 - MAE: 0.0025 - MAPE: 1268666.0000 - RMSE: 0.0365 - val_loss: 0.0093 - val_accuracy: 0.9974 - val_Recall: 0.9974 - val_Precision: 0.9974 - val_AUC: 0.9998 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_f1_score: 0.9974 - val_MAE: 0.0037 - val_MAPE: 1850515.8750 - val_RMSE: 0.0486 - lr: 2.5000e-05
# Epoch 39/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989 - Recall: 0.9989 - Precision: 0.9989 - AUC: 0.9999 - false_positives: 67.0000 - false_negatives: 67.0000 - f1_score: 0.9989 - MAE: 0.0019 - MAPE: 935372.8750 - RMSE: 0.0296
# Epoch 39: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3478s 446ms/step - loss: 0.0035 - accuracy: 0.9989 - Recall: 0.9989 - Precision: 0.9989 - AUC: 0.9999 - false_positives: 67.0000 - false_negatives: 67.0000 - f1_score: 0.9989 - MAE: 0.0019 - MAPE: 935372.8750 - RMSE: 0.0296 - val_loss: 0.0056 - val_accuracy: 0.9978 - val_Recall: 0.9978 - val_Precision: 0.9978 - val_AUC: 0.9999 - val_false_positives: 24.0000 - val_false_negatives: 24.0000 - val_f1_score: 0.9978 - val_MAE: 0.0025 - val_MAPE: 1244563.0000 - val_RMSE: 0.0400 - lr: 2.5000e-05
# Epoch 40/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986 - Recall: 0.9986 - Precision: 0.9986 - AUC: 0.9999 - false_positives: 90.0000 - false_negatives: 90.0000 - f1_score: 0.9986 - MAE: 0.0020 - MAPE: 1001275.5000 - RMSE: 0.0330
# Epoch 40: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3481s 446ms/step - loss: 0.0041 - accuracy: 0.9986 - Recall: 0.9986 - Precision: 0.9986 - AUC: 0.9999 - false_positives: 90.0000 - false_negatives: 90.0000 - f1_score: 0.9986 - MAE: 0.0020 - MAPE: 1001275.5000 - RMSE: 0.0330 - val_loss: 0.0069 - val_accuracy: 0.9985 - val_Recall: 0.9985 - val_Precision: 0.9985 - val_AUC: 0.9995 - val_false_positives: 17.0000 - val_false_negatives: 17.0000 - val_f1_score: 0.9985 - val_MAE: 0.0021 - val_MAPE: 1056317.7500 - val_RMSE: 0.0385 - lr: 2.5000e-05
# Epoch 41/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 101.0000 - false_negatives: 101.0000 - f1_score: 0.9984 - MAE: 0.0022 - MAPE: 1096699.3750 - RMSE: 0.0342
# Epoch 41: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3480s 446ms/step - loss: 0.0041 - accuracy: 0.9984 - Recall: 0.9984 - Precision: 0.9984 - AUC: 0.9999 - false_positives: 101.0000 - false_negatives: 101.0000 - f1_score: 0.9984 - MAE: 0.0022 - MAPE: 1096699.3750 - RMSE: 0.0342 - val_loss: 0.0104 - val_accuracy: 0.9961 - val_Recall: 0.9961 - val_Precision: 0.9961 - val_AUC: 0.9999 - val_false_positives: 43.0000 - val_false_negatives: 43.0000 - val_f1_score: 0.9961 - val_MAE: 0.0047 - val_MAPE: 2354984.0000 - val_RMSE: 0.0549 - lr: 2.5000e-05
# Epoch 42/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9987 - Recall: 0.9987 - Precision: 0.9987 - AUC: 0.9999 - false_positives: 83.0000 - false_negatives: 83.0000 - f1_score: 0.9987 - MAE: 0.0019 - MAPE: 968834.6250 - RMSE: 0.0316
# Epoch 42: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3482s 446ms/step - loss: 0.0036 - accuracy: 0.9987 - Recall: 0.9987 - Precision: 0.9987 - AUC: 0.9999 - false_positives: 83.0000 - false_negatives: 83.0000 - f1_score: 0.9987 - MAE: 0.0019 - MAPE: 968834.6250 - RMSE: 0.0316 - val_loss: 0.0205 - val_accuracy: 0.9944 - val_Recall: 0.9944 - val_Precision: 0.9944 - val_AUC: 0.9993 - val_false_positives: 62.0000 - val_false_negatives: 62.0000 - val_f1_score: 0.9944 - val_MAE: 0.0064 - val_MAPE: 3215062.2500 - val_RMSE: 0.0687 - lr: 2.5000e-05
# Epoch 43/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9987 - Recall: 0.9987 - Precision: 0.9987 - AUC: 0.9999 - false_positives: 81.0000 - false_negatives: 81.0000 - f1_score: 0.9987 - MAE: 0.0019 - MAPE: 967776.3750 - RMSE: 0.0315
# Epoch 43: val_accuracy did not improve from 0.99900
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 7807/7807 [==============================] - 3481s 446ms/step - loss: 0.0036 - accuracy: 0.9987 - Recall: 0.9987 - Precision: 0.9987 - AUC: 0.9999 - false_positives: 81.0000 - false_negatives: 81.0000 - f1_score: 0.9987 - MAE: 0.0019 - MAPE: 967776.3750 - RMSE: 0.0315 - val_loss: 0.0059 - val_accuracy: 0.9985 - val_Recall: 0.9985 - val_Precision: 0.9985 - val_AUC: 0.9997 - val_false_positives: 17.0000 - val_false_negatives: 17.0000 - val_f1_score: 0.9985 - val_MAE: 0.0020 - val_MAPE: 985412.8125 - val_RMSE: 0.0360 - lr: 2.5000e-05
# Epoch 44/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989 - Recall: 0.9989 - Precision: 0.9989 - AUC: 0.9998 - false_positives: 70.0000 - false_negatives: 70.0000 - f1_score: 0.9989 - MAE: 0.0016 - MAPE: 797086.0625 - RMSE: 0.0288
# Epoch 44: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3480s 446ms/step - loss: 0.0031 - accuracy: 0.9989 - Recall: 0.9989 - Precision: 0.9989 - AUC: 0.9998 - false_positives: 70.0000 - false_negatives: 70.0000 - f1_score: 0.9989 - MAE: 0.0016 - MAPE: 797086.0625 - RMSE: 0.0288 - val_loss: 0.0079 - val_accuracy: 0.9974 - val_Recall: 0.9974 - val_Precision: 0.9974 - val_AUC: 0.9999 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_f1_score: 0.9974 - val_MAE: 0.0030 - val_MAPE: 1504942.7500 - val_RMSE: 0.0451 - lr: 1.2500e-05
# Epoch 45/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 0.9998 - false_positives: 49.0000 - false_negatives: 49.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 614490.8750 - RMSE: 0.0255
# Epoch 45: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0027 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 0.9998 - false_positives: 49.0000 - false_negatives: 49.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 614490.8750 - RMSE: 0.0255 - val_loss: 0.0101 - val_accuracy: 0.9973 - val_Recall: 0.9973 - val_Precision: 0.9973 - val_AUC: 0.9998 - val_false_positives: 30.0000 - val_false_negatives: 30.0000 - val_f1_score: 0.9973 - val_MAE: 0.0034 - val_MAPE: 1710960.8750 - val_RMSE: 0.0475 - lr: 1.2500e-05
# Epoch 46/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 0.9999 - false_positives: 49.0000 - false_negatives: 49.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 622367.8125 - RMSE: 0.0252
# Epoch 46: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0024 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 0.9999 - false_positives: 49.0000 - false_negatives: 49.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 622367.8125 - RMSE: 0.0252 - val_loss: 0.0031 - val_accuracy: 0.9988 - val_Recall: 0.9988 - val_Precision: 0.9988 - val_AUC: 0.9999 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_f1_score: 0.9988 - val_MAE: 0.0013 - val_MAPE: 670983.6250 - val_RMSE: 0.0282 - lr: 1.2500e-05
# Epoch 47/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993 - Recall: 0.9993 - Precision: 0.9993 - AUC: 1.0000 - false_positives: 46.0000 - false_negatives: 46.0000 - f1_score: 0.9993 - MAE: 0.0011 - MAPE: 531134.7500 - RMSE: 0.0233
# Epoch 47: val_accuracy did not improve from 0.99900
# 7807/7807 [==============================] - 3477s 445ms/step - loss: 0.0019 - accuracy: 0.9993 - Recall: 0.9993 - Precision: 0.9993 - AUC: 1.0000 - false_positives: 46.0000 - false_negatives: 46.0000 - f1_score: 0.9993 - MAE: 0.0011 - MAPE: 531134.7500 - RMSE: 0.0233 - val_loss: 0.0040 - val_accuracy: 0.9988 - val_Recall: 0.9988 - val_Precision: 0.9988 - val_AUC: 0.9997 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_f1_score: 0.9988 - val_MAE: 0.0015 - val_MAPE: 763414.4375 - val_RMSE: 0.0316 - lr: 1.2500e-05
# Epoch 48/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 1.0000 - false_positives: 50.0000 - false_negatives: 50.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 592322.9375 - RMSE: 0.0253
# Epoch 48: val_accuracy improved from 0.99900 to 0.99918, saving model to /home/user/Desktop/personal/linkon/Alzheimer/oasis_code/Weights/oasis-2-class-not-balanced-3-oct.keras
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0024 - accuracy: 0.9992 - Recall: 0.9992 - Precision: 0.9992 - AUC: 1.0000 - false_positives: 50.0000 - false_negatives: 50.0000 - f1_score: 0.9992 - MAE: 0.0012 - MAPE: 592322.9375 - RMSE: 0.0253 - val_loss: 0.0032 - val_accuracy: 0.9992 - val_Recall: 0.9992 - val_Precision: 0.9992 - val_AUC: 0.9997 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_f1_score: 0.9992 - val_MAE: 0.0012 - val_MAPE: 601859.3750 - val_RMSE: 0.0266 - lr: 1.2500e-05
# Epoch 49/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9991 - Recall: 0.9991 - Precision: 0.9991 - AUC: 0.9999 - false_positives: 56.0000 - false_negatives: 56.0000 - f1_score: 0.9991 - MAE: 0.0012 - MAPE: 587094.7500 - RMSE: 0.0258
# Epoch 49: val_accuracy did not improve from 0.99918
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0024 - accuracy: 0.9991 - Recall: 0.9991 - Precision: 0.9991 - AUC: 0.9999 - false_positives: 56.0000 - false_negatives: 56.0000 - f1_score: 0.9991 - MAE: 0.0012 - MAPE: 587094.7500 - RMSE: 0.0258 - val_loss: 0.0046 - val_accuracy: 0.9985 - val_Recall: 0.9985 - val_Precision: 0.9985 - val_AUC: 0.9999 - val_false_positives: 17.0000 - val_false_negatives: 17.0000 - val_f1_score: 0.9985 - val_MAE: 0.0018 - val_MAPE: 916264.8125 - val_RMSE: 0.0336 - lr: 1.2500e-05
# Epoch 50/50
# 7807/7807 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9991 - Recall: 0.9991 - Precision: 0.9991 - AUC: 1.0000 - false_positives: 57.0000 - false_negatives: 57.0000 - f1_score: 0.9991 - MAE: 0.0012 - MAPE: 621498.6875 - RMSE: 0.0257
# Epoch 50: val_accuracy did not improve from 0.99918
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 7807/7807 [==============================] - 3479s 446ms/step - loss: 0.0023 - accuracy: 0.9991 - Recall: 0.9991 - Precision: 0.9991 - AUC: 1.0000 - false_positives: 57.0000 - false_negatives: 57.0000 - f1_score: 0.9991 - MAE: 0.0012 - MAPE: 621498.6875 - RMSE: 0.0257 - val_loss: 0.0089 - val_accuracy: 0.9976 - val_Recall: 0.9976 - val_Precision: 0.9976 - val_AUC: 0.9996 - val_false_positives: 27.0000 - val_false_negatives: 27.0000 - val_f1_score: 0.9976 - val_MAE: 0.0027 - val_MAPE: 1359737.5000 - val_RMSE: 0.0438 - lr: 1.2500e-05

# %%
import pandas as pd

history_df = pd.DataFrame()


for col in history.history.keys():
    history_df[col] = history.history[col]

history_df.head()
history_df.to_csv('./Proposed_model_2_class_oasis_not_balanced.csv', index=False)

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'Recall', 'Precision', 'AUC', 'false_positives', 'false_negatives', 'f1_score', 'MAE', 'MAPE', 'RMSE', 'val_loss', 'val_accuracy', 'val_Recall', 'val_Precision', 'val_AUC', 'val_false_positives', 'val_false_negatives', 'val_f1_score', 'val_MAE', 'val_MAPE', 'val_RMSE', 'lr'])

# %%
model.load_weights(checkpoint_path)

# %%
# print(model.evaluate(train_images, train_one_hot))

# %%
# print(model.evaluate(val_gen))

# %%
# print(model.evaluate(test_images, test_one_hot))

# %%
print(model.evaluate(test_gen))
# Out:
# /home/user/anaconda3/envs/ecg/lib/python3.9/site-packages/keras/src/engine/training.py:2723: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# /home/user/anaconda3/envs/ecg/lib/python3.9/site-packages/keras/src/engine/training.py:2723: UserWarning: Metric RootMeanSquaredError implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 12966/12966 [==============================] - 2300s 177ms/step - loss: 0.0018 - accuracy: 0.9995 - Recall: 0.9995 - Precision: 0.9995 - AUC: 0.9997 - false_positives: 7.0000 - false_negatives: 7.0000 - f1_score: 0.9995 - MAE: 7.1613e-04 - MAPE: 358065.4688 - RMSE: 0.0203
# [0.0017838597996160388, 0.9994601011276245, 0.9994601011276245, 0.9994601011276245, 0.9996510744094849, 7.0, 7.0, 0.9994600415229797, 0.000716132577508688, 358065.46875, 0.020262256264686584]

# %%
# Y_prob = model.predict(test_images[:2000])
# print(Y_prob)

# %%
# y_pred = np.argmax(Y_prob, axis=1)
# y_pred

# %%
# np.argmax(test_one_hot, axis=1)

# %%
# test_encoded_labels

# %%
# true_labels = np.argmax(test_one_hot, axis=1)


# num_images = min(12, len(test_images))  # Ensure we don't exceed the number of images available
# columns = 4
# rows = (num_images + columns - 1) // columns  
# fig = plt.figure(figsize=(10, 10))
# label_names = classes  

# for i in range(1, num_images + 1):
#     fig.add_subplot(rows, columns, i)
#     plt.imshow(test_images[i - 1])
# #     actual_label = label_names[true_labels[i - 1]]
#     actual_label = label_names[test_encoded_labels[i - 1]]
#     predicted_label = label_names[y_pred[i - 1]]
#     plt.title(f'Actual: {actual_label}\nPred: {predicted_label}')
#     plt.axis('off')  

# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import classification_report


# # Compute accuracy score
# report = classification_report(test_encoded_labels, y_pred, target_names=classes)

# # Print classification report
# print("Classification Report:")
# print(report)

# %%
# def calculate_metrics(pred_classes, gt_classes):
    


#     accuracy = np.mean(pred_classes == gt_classes)

   
#     confusion_matrix = np.zeros((4, 4), dtype=int)
#     np.add.at(confusion_matrix, (gt_classes, pred_classes), 1)

#     sensitivity = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis=1)

#     true_negatives = np.sum(confusion_matrix) - np.sum(np.diag(confusion_matrix))
#     specificity = true_negatives / (np.sum(confusion_matrix) - np.sum(np.diag(confusion_matrix)))

#     metrics = {
#         'accuracy': accuracy,
#         'sensitivity': sensitivity,
#         'specificity': specificity
#     }
    
#     return metrics

# %%
# print(calculate_metrics(y_pred, test_encoded_labels))

# %%
# def plot_confusion_matrix (cm):
#     plt.figure(figsize = (10,10))
#     sns.heatmap(
#         cm, 
#         cmap = 'Reds', 
#         linecolor = 'black', 
#         linewidth = 1, 
#         annot = True, 
#         fmt = '', 
#         xticklabels = classes, 
#         yticklabels = classes)
    
#     plt.xlabel('Predicted label')
#     plt.ylabel('True label')
#     plt.title('Confusion Matrix')
#     plt.show()

# %%
# from sklearn.metrics import confusion_matrix
# plot_confusion_matrix(confusion_matrix(test_encoded_labels, y_pred))

# %%
# def plot_confusion_matrix_perc(cm, classes):
#     # Convert confusion matrix to percentages
#     cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
    
#     plt.figure(figsize=(10, 10))
#     sns.heatmap(
#         cm_percentage, 
#         cmap='Reds', 
#         linecolor='black', 
#         linewidth=1, 
#         annot=True, 
#         fmt='.2f',  # format the annotations to 2 decimal places
#         xticklabels=classes, 
#         yticklabels=classes
#     )
#     plt.xlabel('Predicted label')
#     plt.ylabel('True label')
#     plt.title('Confusion Matrix (Percentage)')
#     plt.show()

# %%
# from sklearn.metrics import confusion_matrix
# plot_confusion_matrix_perc(confusion_matrix(test_encoded_labels, y_pred), classes)
